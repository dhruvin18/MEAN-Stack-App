# %%
#for mounting drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Reading cleaned dataset
import pandas as pd
path = '/content/drive/My Drive/BE PROJECT/Lawgical Final/LabelledDataset/'
df = pd.read_csv(path+'cleaned_dataset_new.csv')

# %%
# Splitting the dataset into train and test sets
X = df.loc[:,'Judgement'].values
y = df.loc[:,'label'].values
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=52)

# %%
# Vectorizinf the corpus using TFIDF Vectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(ngram_range = (1,2),max_features=10000) 
train_vectors = vectorizer.fit_transform(X_train)
test_vectors = vectorizer.transform(X_test)
print(train_vectors.shape, test_vectors.shape)
# Out:
# (1192, 10000) (512, 10000)

# %%
! pip install -q scikit-plot

# %%
from  sklearn.metrics  import accuracy_score
from  sklearn.metrics  import recall_score
from  sklearn.metrics  import precision_score
from sklearn.metrics import confusion_matrix
import scikitplot as skplt

# %%
# Algorithm 3 : SVM

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import CountVectorizer
text_clf = Pipeline([ ('vect', CountVectorizer()), ('tfidf', TfidfTransformer()), ('clf', SGDClassifier(loss='hinge', penalty='l2', alpha=1e-3, random_state=52, max_iter=5, tol=None)),])

text_clf.fit(X_train, y_train)

predicted = text_clf.predict(X_test)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.681640625
# Recall Score =  0.7508196721311475
# Precision Score =  0.7246835443037974

# %%
from sklearn.svm import LinearSVC
svm = LinearSVC()
svm.fit(train_vectors, y_train)

predicted = svm.predict(test_vectors)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.71484375
# Recall Score =  0.780327868852459
# Precision Score =  0.750788643533123

# %%
from sklearn.svm import LinearSVC
svm = LinearSVC(loss='hinge', penalty='l2', random_state=52, max_iter=5000)
svm.fit(train_vectors, y_train)

predicted = svm.predict(test_vectors)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.69921875
# Recall Score =  0.7967213114754098
# Precision Score =  0.7253731343283583

# %%
from sklearn.svm import LinearSVC
svm = LinearSVC(penalty='l1', dual=False)
svm.fit(train_vectors, y_train)

predicted = svm.predict(test_vectors)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.693359375
# Recall Score =  0.760655737704918
# Precision Score =  0.7341772151898734

# %%
from sklearn.svm import LinearSVC
svm = LinearSVC(loss='hinge')
svm.fit(train_vectors, y_train)

predicted = svm.predict(test_vectors)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.69921875
# Recall Score =  0.7967213114754098
# Precision Score =  0.7253731343283583

# %%
from sklearn.svm import LinearSVC
svm = LinearSVC(multi_class='crammer_singer')
svm.fit(train_vectors, y_train)

predicted = svm.predict(test_vectors)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.6953125
# Recall Score =  0.7475409836065574
# Precision Score =  0.742671009771987

# %%
from sklearn.svm import LinearSVC
svm = LinearSVC(fit_intercept=False)
svm.fit(train_vectors, y_train)

predicted = svm.predict(test_vectors)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.712890625
# Recall Score =  0.7770491803278688
# Precision Score =  0.75

# %%
from sklearn.svm import LinearSVC
svm = LinearSVC(class_weight='balanced')
svm.fit(train_vectors, y_train)

predicted = svm.predict(test_vectors)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.703125
# Recall Score =  0.7147540983606557
# Precision Score =  0.7703180212014135

# %%
from sklearn.svm import LinearSVC
svm = LinearSVC(fit_intercept=False, class_weight='balanced')
svm.fit(train_vectors, y_train)

predicted = svm.predict(test_vectors)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.705078125
# Recall Score =  0.7147540983606557
# Precision Score =  0.7730496453900709

# %%
from sklearn.svm import LinearSVC
svm = LinearSVC(fit_intercept=False, class_weight='balanced', random_state=52)
svm.fit(train_vectors, y_train)

predicted = svm.predict(test_vectors)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.705078125
# Recall Score =  0.7147540983606557
# Precision Score =  0.7730496453900709

# %%
from sklearn.svm import LinearSVC
svm = LinearSVC(random_state=52)
svm.fit(train_vectors, y_train)

predicted = svm.predict(test_vectors)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.71484375
# Recall Score =  0.780327868852459
# Precision Score =  0.750788643533123

# %%
from sklearn.svm import LinearSVC
svm = LinearSVC(max_iter=50000)
svm.fit(train_vectors, y_train)

predicted = svm.predict(test_vectors)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.71484375
# Recall Score =  0.780327868852459
# Precision Score =  0.750788643533123

# %%
#scaling inputvectors using maxabsscaler
from sklearn import preprocessing
max_abs_scaler = preprocessing.MaxAbsScaler()
X_train_mabs= max_abs_scaler.fit_transform(train_vectors)
X_test_mabs= max_abs_scaler.transform(test_vectors)

# %%
from sklearn.svm import LinearSVC
svm = LinearSVC()
svm.fit(X_train_mabs, y_train)

predicted = svm.predict(X_test_mabs)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.740234375
# Recall Score =  0.7901639344262295
# Precision Score =  0.7774193548387097

# %%
#scaling inputvectors using standard sscaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler(with_mean=False)
X_train_stds= scaler.fit_transform(train_vectors)
X_test_stds= scaler.transform(test_vectors)

# %%
from sklearn.svm import LinearSVC
svm = LinearSVC()
svm.fit(X_train_stds, y_train)

predicted = svm.predict(X_test_stds)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.736328125
# Recall Score =  0.7967213114754098
# Precision Score =  0.7689873417721519
# /usr/local/lib/python3.6/dist-packages/sklearn/svm/_base.py:947: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %%
from sklearn.svm import LinearSVC
svm = LinearSVC(max_iter=5000)
svm.fit(X_train_mabs, y_train)

predicted = svm.predict(X_test_mabs)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.740234375
# Recall Score =  0.7901639344262295
# Precision Score =  0.7774193548387097

# %%
from sklearn.svm import LinearSVC
from sklearn.datasets import load_iris
from sklearn.feature_selection import SelectFromModel

# %%
train_vectors.shape
# Out:
# (1192, 10000)

# %%
lsvc = LinearSVC(C=0.90, penalty="l1", dual=False).fit(train_vectors,y_train)

# %%
model = SelectFromModel(lsvc, prefit=True)

# %%
X_new = model.transform(train_vectors)

# %%
test_new = model.transform(test_vectors)

# %%
print(X_new.shape, test_new.shape)
# Out:
# (1192, 276) (512, 276)

# %%
from sklearn.svm import LinearSVC
svm = LinearSVC()
svm.fit(X_new, y_train)

predicted = svm.predict(test_new)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.677734375
# Recall Score =  0.7704918032786885
# Precision Score =  0.7121212121212122
