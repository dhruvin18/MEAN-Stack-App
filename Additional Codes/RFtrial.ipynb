# %%
#for mounting drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# Reading cleaned dataset
import pandas as pd
path = '/content/drive/My Drive/BE PROJECT/Lawgical Final/LabelledDataset/'
df = pd.read_csv(path+'cleaned_dataset_2.csv')

# %%
# Splitting the dataset into train and test sets
X = df.loc[:,'Judgement'].values
y = df.loc[:,'label'].values
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=52)

# %%
# import pandas as pd
# path = '/content/drive/My Drive/BE PROJECT/Lawgical Final/LabelledDataset/'
# traindf = pd.read_csv(path+'train.csv')
# testdf = pd.read_csv(path+'test.csv')
# X_train = traindf.loc[:,'Judgement'].values
# y_train = traindf.loc[:,'label'].values
# X_test = testdf.loc[:,'Judgement'].values
# y_test = testdf.loc[:,'label'].values

# %%
# Vectorizing the corpus using TFIDF Vectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(ngram_range = (1,2),max_features=10000) 
train_vectors = vectorizer.fit_transform(X_train)
test_vectors = vectorizer.transform(X_test)
print(train_vectors.shape, test_vectors.shape)
# Out:
# (1192, 10000) (512, 10000)

# %%
! pip install -q scikit-plot

# %%
from  sklearn.metrics  import accuracy_score
from  sklearn.metrics  import recall_score
from  sklearn.metrics  import precision_score
from sklearn.metrics import confusion_matrix
import scikitplot as skplt

# %%
# Algorithm 5 : Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier

rfclf=RandomForestClassifier(random_state= 4, bootstrap=False)
rfclf.fit(train_vectors, y_train)

predicted=rfclf.predict(test_vectors)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.787109375
# Recall Score =  0.8950819672131147
# Precision Score =  0.78

# %%
from sklearn.ensemble import RandomForestClassifier

rfclf=RandomForestClassifier(random_state= 52, bootstrap=False)
rfclf.fit(train_vectors, y_train)

predicted=rfclf.predict(test_vectors)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.810546875
# Recall Score =  0.9147540983606557
# Precision Score =  0.7971428571428572

# %%
from sklearn.ensemble import RandomForestClassifier

rfclf=RandomForestClassifier(random_state=52, bootstrap=False, n_estimators=500)
rfclf.fit(train_vectors, y_train)

predicted=rfclf.predict(test_vectors)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.822265625
# Recall Score =  0.940983606557377
# Precision Score =  0.7972222222222223

# %%
from sklearn.ensemble import RandomForestClassifier

rfclf=RandomForestClassifier(random_state=52, bootstrap=False, max_features='auto', n_estimators=500)
rfclf.fit(train_vectors, y_train)

predicted=rfclf.predict(test_vectors)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.822265625
# Recall Score =  0.940983606557377
# Precision Score =  0.7972222222222223

# %%
from sklearn.ensemble import RandomForestClassifier

rfclf=RandomForestClassifier(random_state=4, bootstrap=False, max_features='auto', n_estimators=500)
rfclf.fit(train_vectors, y_train)

predicted=rfclf.predict(test_vectors)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.80859375
# Recall Score =  0.9344262295081968
# Precision Score =  0.7851239669421488

# %%
from sklearn.ensemble import RandomForestClassifier

rfclf=RandomForestClassifier(random_state=4, bootstrap=True, max_features='auto', n_estimators=500, oob_score=True)
rfclf.fit(train_vectors, y_train)

predicted=rfclf.predict(test_vectors)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.798828125
# Recall Score =  0.9442622950819672
# Precision Score =  0.7700534759358288

# %%
from sklearn.ensemble import RandomForestClassifier

rfclf=RandomForestClassifier(random_state=4, bootstrap=True, max_features='auto', n_estimators=500, oob_score=False)
rfclf.fit(train_vectors, y_train)

predicted=rfclf.predict(test_vectors)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.798828125
# Recall Score =  0.9442622950819672
# Precision Score =  0.7700534759358288

# %%
from sklearn.ensemble import RandomForestClassifier

rfclf=RandomForestClassifier(random_state=52, bootstrap=False, max_features='auto', n_estimators=1000, class_weight='balanced')
rfclf.fit(train_vectors, y_train)

predicted=rfclf.predict(test_vectors)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.83203125
# Recall Score =  0.9442622950819672
# Precision Score =  0.8067226890756303

# %%
from sklearn.ensemble import RandomForestClassifier

rfclf=RandomForestClassifier(random_state=52, bootstrap=False, max_features='auto', n_estimators=1000, class_weight='balanced_subsample')
rfclf.fit(train_vectors, y_train)

predicted=rfclf.predict(test_vectors)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.82421875
# Recall Score =  0.9278688524590164
# Precision Score =  0.8062678062678063

# %%
# Reading cleaned dataset
import pandas as pd
path = '/content/drive/My Drive/BE PROJECT/Lawgical Final/LabelledDataset/'
df = pd.read_csv(path+'cleaned_dataset_new.csv')

# %%
# Splitting the dataset into train and test sets
X = df.loc[:,'Judgement'].values
y = df.loc[:,'label'].values
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=52)

# %%
# Vectorizing the corpus using TFIDF Vectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(ngram_range = (1,2),max_features=10000) 
train_vectors = vectorizer.fit_transform(X_train)
test_vectors = vectorizer.transform(X_test)
print(train_vectors.shape, test_vectors.shape)
# Out:
# (1192, 10000) (512, 10000)

# %%
#scaling inputvectors using maxabsscaler
from sklearn import preprocessing
max_abs_scaler = preprocessing.MaxAbsScaler()
X_train_mabs= max_abs_scaler.fit_transform(train_vectors)
X_test_mabs= max_abs_scaler.transform(test_vectors)

# %%
from sklearn.ensemble import RandomForestClassifier

rfclf=RandomForestClassifier(random_state=52, bootstrap=False, max_features='auto', n_estimators=1000, class_weight='balanced')
rfclf.fit(X_train_mabs, y_train)

predicted=rfclf.predict(X_test_mabs)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.83203125
# Recall Score =  0.9442622950819672
# Precision Score =  0.8067226890756303

# %%
from sklearn.ensemble import RandomForestClassifier

rfclf=RandomForestClassifier(random_state=52, bootstrap=False, max_features='auto', n_estimators=1000)
rfclf.fit(X_train_mabs, y_train)

predicted=rfclf.predict(X_test_mabs)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.80859375
# Recall Score =  0.9311475409836065
# Precision Score =  0.7867036011080333

# %%
#scaling inputvectors using standard sscaler
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler(with_mean=False)
X_train_stds= scaler.fit_transform(train_vectors)
X_test_stds= scaler.transform(test_vectors)

# %%
from sklearn.ensemble import RandomForestClassifier

rfclf=RandomForestClassifier(random_state=52, bootstrap=False, max_features='auto', n_estimators=1000, class_weight='balanced')
rfclf.fit(X_train_stds, y_train)

predicted=rfclf.predict(X_test_stds)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))

# %%
from sklearn.ensemble import RandomForestClassifier

rfclf=RandomForestClassifier(random_state=52, bootstrap=False, max_features='auto', n_estimators=1000)
rfclf.fit(X_train_stds, y_train)

predicted=rfclf.predict(X_test_stds)
print('Accuracy Score = ',accuracy_score(y_test,predicted))
print('Recall Score = ',recall_score(y_test,predicted))
print('Precision Score = ',precision_score(y_test,predicted))
skplt.metrics.plot_confusion_matrix(y_test, predicted, figsize=(4,4))
# Out:
# Accuracy Score =  0.80859375
# Recall Score =  0.9311475409836065
# Precision Score =  0.7867036011080333
